# %% [markdown]
# CreditOne - EDA

# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset
credit = pd.read_csv('default of credit card clients.csv', header = 1)

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
credit.isnull()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# 5      False      False  False      False     False  False  False  False
# 6      False      False  False      False     False  False  False  False
# 7      False      False  False      False     False  False  False  False
# 8      False      False  False      False     False  False  False  False
# 9      False      False  False      False     False  False  False  False
# 10     False      False  False      False     False  False  False  False
# 11     False      False  False      False     False  False  False  False
# ...

# %%
creditDF = credit

# %%
# Cleaning up of the DF

creditDF.columns = [x.lower() for x in creditDF.columns]
creditDF = creditDF.rename(index = str, columns = {"pay_0" : "pay_1"})
creditDF = creditDF.rename(index = str, columns = {"default payment next month" : "defaults"})
creditDF = creditDF.drop( 'id', axis =1)
creditDF.columns
# Out:
# Index(['limit_bal', 'sex', 'education', 'marriage', 'age', 'pay_1', 'pay_2',
#        'pay_3', 'pay_4', 'pay_5', 'pay_6', 'bill_amt1', 'bill_amt2',
#        'bill_amt3', 'bill_amt4', 'bill_amt5', 'bill_amt6', 'pay_amt1',
#        'pay_amt2', 'pay_amt3', 'pay_amt4', 'pay_amt5', 'pay_amt6', 'defaults'],
#       dtype='object')

# %%
# Grouping age into bins using the cut()

creditDF['age_bin'] = pd.cut(creditDF['age'], 6, labels=["20", "30", "40", "50", "60", "70"])
creditDF['age_bin']
# Out:
# 0        20
# 1        20
# 2        30
# 3        30
# 4        50
# 5        30
# 6        20
# 7        20
# 8        20
# 9        30
# 10       30
# 11       50
# 12       40
# 13       20
# 14       20
# 15       20
# 16       20
# 17       40
# 18       40
# 19       20
# 20       30
# 21       30
# 22       20
# 23       30
# 24       20
# 25       20
# 26       20
# 27       20
# 28       40
# 29       20
#          ..
# 29970    30
# 29971    30
# 29972    30
# 29973    30
# 29974    30
# 29975    40
# 29976    40
# 29977    30
# 29978    30
# 29979    30
# 29980    40
# 29981    40
# 29982    30
# 29983    40
# 29984    30
# 29985    20
# 29986    30
# 29987    30
# 29988    30
# 29989    30
# 29990    40
# 29991    30
# 29992    40
# 29993    30
# 29994    30
# 29995    30
# 29996    40
# 29997    30
# 29998    40
# 29999    40
# Name: age_bin, Length: 30000, dtype: category
# Categories (6, object): [20 < 30 < 40 < 50 < 60 < 70]

# %%
# Grouping limit_bal into bins using the cut()

creditDF['limit_bal_bin'] = pd.cut(creditDF['limit_bal'],10, 
                                   labels=["10K","20K", "30K", "40K", "50K", "60K", "70K","80K","90K","100K"])

creditDF['limit_bal_bin']
# Out:
# 0        10K
# 1        20K
# 2        10K
# 3        10K
# 4        10K
# 5        10K
# 6        50K
# 7        10K
# 8        20K
# 9        10K
# 10       20K
# 11       30K
# 12       70K
# 13       10K
# 14       30K
# 15       10K
# 16       10K
# 17       40K
# 18       40K
# 19       20K
# 20       20K
# 21       20K
# 22       10K
# 23       50K
# 24       10K
# 25       10K
# 26       10K
# 27       10K
# 28       10K
# 29       10K
#         ...
# 29970    40K
# 29971    10K
# 29972    20K
# 29973    30K
# 29974    10K
# 29975    30K
# 29976    10K
# 29977    50K
# 29978    40K
# 29979    20K
# 29980    10K
# 29981    10K
# 29982    10K
# 29983    10K
# 29984    10K
# 29985    30K
# 29986    40K
# 29987    20K
# 29988    30K
# 29989    20K
# 29990    20K
# 29991    30K
# 29992    10K
# 29993    10K
# 29994    10K
# 29995    30K
# 29996    20K
# 29997    10K
# 29998    10K
# 29999    10K
# Name: limit_bal_bin, Length: 30000, dtype: category
# ...

# %%
# first 10 rows of the DF
creditDF[:10]
# Out:
#    limit_bal  sex  education  marriage  age  pay_1  pay_2  pay_3  pay_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
# 5      50000    1          1         2   37      0      0      0      0
# 6     500000    1          1         2   29      0      0      0      0
# 7     100000    2          2         2   23      0     -1     -1      0
# 8     140000    2          3         1   28      0      0      2      0
# 9      20000    1          3         2   35     -2     -2     -2     -2
#
#    pay_5      ...        bill_amt6  pay_amt1  pay_amt2  pay_amt3  pay_amt4  \
# 0     -2      ...                0         0       689         0         0
# ...

# %%
# Pivot tables
creditDF.pivot_table('defaults', 'limit_bal_bin',aggfunc = len, margins = True)
# Out:
#                defaults
# limit_bal_bin
# 10K               12498
# 20K                7880
# 30K                5059
# 40K                2759
# 50K                1598
# 60K                 127
# 70K                  56
# 80K                  22
# 100K                  1
# All               30000

# %%
creditDF.pivot_table('defaults', 'education',aggfunc = len, margins = True)
# Out:
#            defaults
# education
# 0                14
# 1             10585
# 2             14030
# 3              4917
# 4               123
# 5               280
# 6                51
# All           30000

# %%
creditDF.pivot_table('defaults', 'sex','marriage',aggfunc = len, margins = True)
# Out:
# marriage   0      1      2    3    All
# sex
# 1         14   5190   6553  131  11888
# 2         40   8469   9411  192  18112
# All       54  13659  15964  323  30000

# %%
creditDF.pivot_table('defaults', 'age_bin',aggfunc = len, margins = True)
# Out:
#          defaults
# age_bin
# 20          11013
# 30          10713
# 40           6005
# 50           1930
# 60            314
# 70             25
# All         30000

# %%
# Visualization of individual attributes
plt.hist(creditDF['age'], bins=10)
plt.show()

# %%
plt.hist(creditDF['limit_bal'], bins=10)
plt.show()

# %%
#  1 = graduate school; 2 = university; 3 = high school; 0, 4, 5, 6 = others
plt.hist(creditDF['education']) 
plt.show()

# %%
#  1 = Male & 2 = Female
plt.hist(creditDF['sex']) 
plt.show()

# %%
# 0 = others; 1 = married; 2 = single; 3 = divorce
plt.hist(creditDF['marriage']) 
plt.show()

# %%
#  0 = not default; 1 = default
plt.hist(creditDF['defaults']) 
plt.show()

# %%
# Distribution of age, with an overlay of a density plot
sns.distplot(creditDF['age']).set_title("Distribution of Customers' ages")
# Out:
# C:\Users\kavit\Anaconda3.5\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5,1,"Distribution of Customers' ages")

# %%
sns.catplot('limit_bal_bin', data = creditDF, kind = 'count')

# %%
# Visualization using plt.subplots - Defaults vs others
fig, ax = plt.subplots(1,3)
fig.set_size_inches(20,5)

d = creditDF.groupby(['defaults', 'marriage']).size()
p = d.unstack(level=1).plot(kind='bar', ax=ax[0])

d = creditDF.groupby(['defaults', 'sex']).size()
p = d.unstack(level=1).plot(kind='bar', ax=ax[1])

d = creditDF.groupby(['defaults', 'age_bin']).size()
p = d.unstack(level=1).plot(kind='bar', ax=ax[2])

# %%
# Visualization using plt.subplots - Defaults vs others
fig, ax = plt.subplots(1,2)
fig.set_size_inches(20,5)

d = creditDF.groupby(['defaults', 'education']).size()
p = d.unstack(level=1).plot(kind='bar', ax=ax[0])

d = creditDF.groupby(['defaults', 'limit_bal_bin']).size()
p = d.unstack(level=1).plot(kind='bar', ax=ax[1])

# %%
# Visualization using plt.subplots - limit_bin_bal vs age_bin & education
fig, ax = plt.subplots(1,2)
fig.set_size_inches(20,5)

d = creditDF.groupby(['limit_bal_bin', 'education']).size()
p = d.unstack(level=1).plot(kind='bar', ax=ax[0])

d = creditDF.groupby(['limit_bal_bin', 'age_bin']).size()
p = d.unstack(level=1).plot(kind='bar', ax=ax[1])

# %%
# using catplot from seaborn for visualization of numeric data
sns.catplot('pay_1', data = creditDF, kind = 'count')

# %%
creditDF[['pay_1','pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6']].head(10)
# Out:
#    pay_1  pay_2  pay_3  pay_4  pay_5  pay_6
# 0      2      2     -1     -1     -2     -2
# 1     -1      2      0      0      0      2
# 2      0      0      0      0      0      0
# 3      0      0      0      0      0      0
# 4     -1      0     -1      0      0      0
# 5      0      0      0      0      0      0
# 6      0      0      0      0      0      0
# 7      0     -1     -1      0      0     -1
# 8      0      0      2      0      0      0
# 9     -2     -2     -2     -2     -1     -1

# %%
# using subplot to show the distrubtion of delays in the past 6 months
fig, ax = plt.subplots(1,3)
fig.set_size_inches(20,5)
fig.suptitle('Distribution of delays in the past 6 months')

d = creditDF.groupby(['pay_1']).size()
p = d.plot(kind='bar',color='orange', ax=ax[0]).set_title("pay_1-Sep")

d = creditDF.groupby(['pay_2']).size()
p = d.plot(kind='bar',color='orange', ax=ax[1]).set_title("pay_2-Aug")

d = creditDF.groupby(['pay_3']).size()
p = d.plot(kind='bar',color='orange', ax=ax[2]).set_title("pay_3-Jul")

fig, ax = plt.subplots(1,3)
fig.set_size_inches(20,5)

d = creditDF.groupby(['pay_4']).size()
p = d.plot(kind='bar',color='orange', ax=ax[0]).set_title("pay_4-Jun")

d = creditDF.groupby(['pay_5']).size()
p = d.plot(kind='bar',color='orange', ax=ax[1]).set_title("pay_5-May")

d = creditDF.groupby(['pay_6']).size()
p = d.plot(kind='bar', color='orange', ax=ax[2]).set_title("pay_6-Apr")

# %%
# using boxplot for bill_amt attributes

A = creditDF['bill_amt1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
boxplots = creditDF[['bill_amt1', 'bill_amt2','bill_amt3','bill_amt4','bill_amt5','bill_amt6']].boxplot(return_type = 'axes')

# %%
fig, ax = plt.subplots(2,3)
fig.set_size_inches(15,10)
fig.suptitle('Boxplots for bill_amts')

creditDF.boxplot(column = 'bill_amt1', ax =ax[0,0])
creditDF.boxplot(column = 'bill_amt2', ax =ax[0,1])
creditDF.boxplot(column = 'bill_amt3', ax =ax[0,2])
creditDF.boxplot(column = 'bill_amt4', ax =ax[1,0])
creditDF.boxplot(column = 'bill_amt5', ax =ax[1,1])
creditDF.boxplot(column = 'bill_amt6', ax =ax[1,2])
plt.show()

# %%
# # using boxplot for pay_amt attributes
boxplots = creditDF[['pay_amt1', 'pay_amt2','pay_amt3','pay_amt4','pay_amt5','pay_amt6']].boxplot(return_type = 'axes')

# %%
fig, ax = plt.subplots(2,3)
fig.set_size_inches(15,10)
fig.suptitle('Boxplots for pay_amts')

creditDF.boxplot(column = 'pay_amt1', ax =ax[0,0])
creditDF.boxplot(column = 'pay_amt2', ax =ax[0,1])
creditDF.boxplot(column = 'pay_amt3', ax =ax[0,2])
creditDF.boxplot(column = 'pay_amt4', ax =ax[1,0])
creditDF.boxplot(column = 'pay_amt5', ax =ax[1,1])
creditDF.boxplot(column = 'pay_amt6', ax =ax[1,2])
plt.show()

# %%
# Correlation matrix
corrMat = creditDF[['limit_bal','bill_amt1', 'bill_amt2','bill_amt3','bill_amt4','bill_amt5','bill_amt6',
                  'pay_amt1','pay_amt2', 'pay_amt3', 'pay_amt4', 'pay_amt5', 'pay_amt6']].corr()

corrMat
# Out:
#            limit_bal  bill_amt1  bill_amt2  bill_amt3  bill_amt4  bill_amt5  \
# limit_bal   1.000000   0.285430   0.278314   0.283236   0.293988   0.295562
# bill_amt1   0.285430   1.000000   0.951484   0.892279   0.860272   0.829779
# bill_amt2   0.278314   0.951484   1.000000   0.928326   0.892482   0.859778
# bill_amt3   0.283236   0.892279   0.928326   1.000000   0.923969   0.883910
# bill_amt4   0.293988   0.860272   0.892482   0.923969   1.000000   0.940134
# bill_amt5   0.295562   0.829779   0.859778   0.883910   0.940134   1.000000
# bill_amt6   0.290389   0.802650   0.831594   0.853320   0.900941   0.946197
# pay_amt1    0.195236   0.140277   0.280365   0.244335   0.233012   0.217031
# pay_amt2    0.178408   0.099355   0.100851   0.316936   0.207564   0.181246
# pay_amt3    0.210167   0.156887   0.150718   0.130011   0.300023   0.252305
# pay_amt4    0.203242   0.158303   0.147398   0.143405   0.130191   0.293118
# ...

# %%
# Heatmap for the Correlation matrix 

sns.heatmap(corrMat, xticklabels=corrMat.columns, yticklabels=corrMat.columns, annot=True)

# %%
# Covariance Matrix

covMat = creditDF[['limit_bal','bill_amt1', 'bill_amt2','bill_amt3','bill_amt4','bill_amt5','bill_amt6',
                  'pay_amt1','pay_amt2', 'pay_amt3', 'pay_amt4', 'pay_amt5', 'pay_amt6']].cov()
covMat
# Out:
#               limit_bal     bill_amt1     bill_amt2     bill_amt3  \
# limit_bal  1.683446e+10  2.727020e+09  2.570130e+09  2.548533e+09
# bill_amt1  2.727020e+09  5.422240e+09  4.986670e+09  4.556511e+09
# bill_amt2  2.570130e+09  4.986670e+09  5.065705e+09  4.582086e+09
# bill_amt3  2.548533e+09  4.556511e+09  4.582086e+09  4.809338e+09
# bill_amt4  2.453926e+09  4.075286e+09  4.086508e+09  4.122238e+09
# bill_amt5  2.331481e+09  3.714795e+09  3.720401e+09  3.726780e+09
# bill_amt6  2.243837e+09  3.519876e+09  3.524868e+09  3.524247e+09
# pay_amt1   4.195711e+08  1.710894e+08  3.305146e+08  2.806565e+08
# pay_amt2   5.333504e+08  1.685692e+08  1.653859e+08  5.064226e+08
# pay_amt3   4.801180e+08  2.034048e+08  1.888731e+08  1.587478e+08
# pay_amt4   4.131202e+08  1.826164e+08  1.643518e+08  1.558003e+08
# pay_amt5   4.305657e+08  1.879091e+08  1.717652e+08  1.904126e+08
# pay_amt6   5.065153e+08  2.347681e+08  2.204845e+08  2.247817e+08
#
# ...

# %%
creditDF.shape
# Out:
# (30000, 26)

# %%
# new csv
creditDF.to_csv('new credit client data final.csv')
